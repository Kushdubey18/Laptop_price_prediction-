# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(
    r"C:\Users\asus\Downloads\anand college 45 days traing\project\Laptop\data\laptop_price.csv",
    encoding='latin1'
)

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df['Company'].nunique()
# Out:
# 19

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df['Company'].unique()
# Out:
# <StringArray>
# [    'Apple',        'HP',      'Acer',      'Asus',      'Dell',    'Lenovo',
#      'Chuwi',       'MSI', 'Microsoft',   'Toshiba',    'Huawei',    'Xiaomi',
#       'Vero',     'Razer',  'Mediacom',   'Samsung',    'Google',   'Fujitsu',
#         'LG']
# Length: 19, dtype: str

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df['Ram'].unique()
# Out:
# <StringArray>
# ['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB']
# Length: 9, dtype: str

# %%
Ram_dic  = {'8GB':1, '16GB':2, '4GB':3, '2GB':4, '12GB':5, '6GB':6, '32GB':7, '24GB':8, '64GB':9}
df['Ram'] = df['Ram'].map(Ram_dic)

# %%
Ram_dic
# Out:
# {'8GB': 1,
#  '16GB': 2,
#  '4GB': 3,
#  '2GB': 4,
#  '12GB': 5,
#  '6GB': 6,
#  '32GB': 7,
#  '24GB': 8,
#  '64GB': 9}

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df['Product'].unique()
# Out:
# <StringArray>
# [                              'MacBook Pro',
#                                'Macbook Air',
#                                     '250 G6',
#                                   'Aspire 3',
#                            'ZenBook UX430UN',
#                                    'Swift 3',
#                              'Inspiron 3567',
#                                'MacBook 12"',
#                          'IdeaPad 320-15IKB',
#                                     'XPS 13',
#  ...
#                                'GE62 Apache',
#                             'Yoga 500-14IBD',
#                       'ZenBook UX305CA-UBM1',
#                             'Aspire ES1-531',
#                        'Pavilion 15-AW003nv',
#                           'Stream 11-Y000na',
#  'X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce',
#                             'Yoga 500-14ISK',
#        '15-AC110nv (i7-6500U/6GB/1TB/Radeon',
#        'X553SA-XX031T (N3050/4GB/500GB/W10)']
# ...

# %%
df = df.sort_values(by='Company').reset_index(drop=True)

# %%
df
# Out:
#       laptop_ID Company                                   Product   TypeName  \
# 0           659    Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce     Gaming
# 1            80    Acer                      Aspire A515-51G-32MX   Notebook
# 2           330    Acer                                  Aspire 5   Notebook
# 3           332    Acer                             Aspire E5-575   Notebook
# 4           377    Acer                                  Aspire 3   Notebook
# ...         ...     ...                                       ...        ...
# 1298       1135    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)   Notebook
# 1299        888  Xiaomi                               Mi Notebook  Ultrabook
# 1300        188  Xiaomi                               Mi Notebook   Notebook
# 1301        521  Xiaomi                               Mi Notebook   Notebook
# 1302        196  Xiaomi                               Mi Notebook  Ultrabook
#
# ...

# %%
df['Inches'].unique()
# Out:
# array([ 1,  2,  5,  7,  4, 11, 12,  6, 15,  8, 10,  3, 17, 16,  9, 14])

# %%
TypeName_dic = {'Notebook':1,          'Ultrabook':2,             'Gaming':3,
 '2 in 1 Convertible':4,            'Netbook':5,        'Workstation':6}
df['TypeName'] = df['TypeName'].map(TypeName_dic )

# %%
TypeName_dic
# Out:
# {'Notebook': 1,
#  'Ultrabook': 2,
#  'Gaming': 3,
#  '2 in 1 Convertible': 4,
#  'Netbook': 5,
#  'Workstation': 6}

# %%
df
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 0           659    Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3
# 1            80    Acer                      Aspire A515-51G-32MX         1
# 2           330    Acer                                  Aspire 5         1
# 3           332    Acer                             Aspire E5-575         1
# 4           377    Acer                                  Aspire 3         1
# ...         ...     ...                                       ...       ...
# 1298       1135    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1
# 1299        888  Xiaomi                               Mi Notebook         2
# 1300        188  Xiaomi                               Mi Notebook         1
# 1301        521  Xiaomi                               Mi Notebook         1
# 1302        196  Xiaomi                               Mi Notebook         2
#
# ...

# %%
df['Memory'].unique()
# Out:
# <StringArray>
# [                      '1TB HDD',                     '256GB SSD',
#                      '128GB SSD',                     '500GB HDD',
#             '32GB Flash Storage',           '128GB Flash Storage',
#                       '16GB SSD',          '256GB SSD +  1TB HDD',
#                       '32GB SSD',          '128GB SSD +  1TB HDD',
#             '16GB Flash Storage',           '512GB Flash Storage',
#                      '512GB SSD',           '256GB Flash Storage',
#             '64GB Flash Storage',          '512GB SSD +  2TB HDD',
#                        '2TB HDD',          '512GB SSD +  1TB HDD',
#                        '1TB SSD',                     '128GB HDD',
#         '256GB SSD +  256GB SSD',        '512GB SSD +  512GB SSD',
#         '256GB SSD +  500GB HDD',                      '64GB SSD',
#             '1TB SSD +  1TB HDD',          '256GB SSD +  2TB HDD',
#                   '1.0TB Hybrid',          '128GB SSD +  2TB HDD',
# ...

# %%
memory_dic = {
    '500GB HDD': 1,
    '2TB HDD': 2,
    '1TB HDD': 3,
    '256GB SSD': 4,
    '128GB SSD +  1TB HDD': 5,
    '128GB SSD': 6,
    '256GB SSD +  1TB HDD': 7,
    '512GB SSD +  1TB HDD': 8,
    '1TB SSD +  1TB HDD': 9,
    '32GB Flash Storage': 10,
    '1.0TB Hybrid': 11,
    '512GB SSD': 12,
    '1TB SSD': 13,
    '32GB SSD': 14,
    '16GB Flash Storage': 15,
    '16GB SSD': 16,
    '64GB Flash Storage': 17,
    '64GB SSD': 18,
    '256GB SSD +  500GB HDD': 19,
    '240GB SSD': 20,
    '256GB SSD +  256GB SSD': 21,
    '256GB SSD +  2TB HDD': 22,
    '512GB SSD +  2TB HDD': 23,
    '1.0TB HDD': 24,
    '512GB SSD +  1.0TB Hybrid': 25,
    '256GB SSD +  1.0TB Hybrid': 26,
    '128GB SSD +  2TB HDD': 27,
    '512GB SSD +  256GB SSD': 28,
    '512GB Flash Storage': 29,
    '256GB Flash Storage': 30,
    '128GB Flash Storage': 31,
    '64GB Flash Storage +  1TB HDD': 32,
    '128GB HDD': 33,
    '32GB HDD': 34,
    '508GB Hybrid': 35,
    '180GB SSD': 36,
    '1TB HDD +  1TB HDD': 37,
    '8GB SSD': 38,
    '512GB SSD +  512GB SSD': 39
}
df['Memory'] = df['Memory'].map(memory_dic)

# %%
memory_dic
# Out:
# {'500GB HDD': 1,
#  '2TB HDD': 2,
#  '1TB HDD': 3,
#  '256GB SSD': 4,
#  '128GB SSD +  1TB HDD': 5,
#  '128GB SSD': 6,
#  '256GB SSD +  1TB HDD': 7,
#  '512GB SSD +  1TB HDD': 8,
#  '1TB SSD +  1TB HDD': 9,
#  '32GB Flash Storage': 10,
#  '1.0TB Hybrid': 11,
#  '512GB SSD': 12,
#  '1TB SSD': 13,
#  '32GB SSD': 14,
#  '16GB Flash Storage': 15,
#  '16GB SSD': 16,
#  '64GB Flash Storage': 17,
#  '64GB SSD': 18,
#  '256GB SSD +  500GB HDD': 19,
#  '240GB SSD': 20,
#  '256GB SSD +  256GB SSD': 21,
#  '256GB SSD +  2TB HDD': 22,
#  '512GB SSD +  2TB HDD': 23,
#  '1.0TB HDD': 24,
#  '512GB SSD +  1.0TB Hybrid': 25,
#  '256GB SSD +  1.0TB Hybrid': 26,
#  '128GB SSD +  2TB HDD': 27,
#  '512GB SSD +  256GB SSD': 28,
#  '512GB Flash Storage': 29,
#  '256GB Flash Storage': 30,
#  '128GB Flash Storage': 31,
#  '64GB Flash Storage +  1TB HDD': 32,
#  '128GB HDD': 33,
#  '32GB HDD': 34,
#  '508GB Hybrid': 35,
#  '180GB SSD': 36,
#  '1TB HDD +  1TB HDD': 37,
#  '8GB SSD': 38,
# ...

# %%
df
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 0           659    Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3
# 1            80    Acer                      Aspire A515-51G-32MX         1
# 2           330    Acer                                  Aspire 5         1
# 3           332    Acer                             Aspire E5-575         1
# 4           377    Acer                                  Aspire 3         1
# ...         ...     ...                                       ...       ...
# 1298       1135    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1
# 1299        888  Xiaomi                               Mi Notebook         2
# 1300        188  Xiaomi                               Mi Notebook         1
# 1301        521  Xiaomi                               Mi Notebook         1
# 1302        196  Xiaomi                               Mi Notebook         2
#
# ...

# %%
df['Gpu'].unique()
# Out:
# <StringArray>
# [ 'Nvidia GeForce GTX 1050',     'Nvidia GeForce MX130',
#         'AMD Radeon RX 540',    'Intel HD Graphics 620',
#             'AMD Radeon R5',    'Intel HD Graphics 520',
#      'Nvidia GeForce 940MX',    'Intel HD Graphics 400',
#  'Nvidia GeForce GTX 940MX',     'Nvidia GeForce MX150',
#  ...
#       'Nvidia Quadro M500M',       'AMD Radeon R7 M460',
#             'AMD Radeon R3',    'Intel HD Graphics 540',
#        'AMD Radeon R9 M385',           'AMD R17M-M1-70',
#        'Nvidia GTX 980 SLI',        'ARM Mali T860 MP4',
#            'AMD Radeon 540',      'Nvidia GeForce 930M']
# Length: 110, dtype: str

# %%
df['OpSys'].unique()
# Out:
# <StringArray>
# [       'Linux',   'Windows 10',    'Chrome OS',     'Mac OS X',
#         'macOS', 'Windows 10 S',        'No OS',    'Windows 7',
#       'Android']
# Length: 9, dtype: str

# %%
OpSys_dic = {'Windows 10':1,'No OS':2,        'Linux':3,    'Windows 7':4,
    'Chrome OS':5, 'Windows 10 S':6,        'macOS':7,     'Mac OS X':8,
      'Android':9}
df['OpSys'] = df['OpSys'].map(OpSys_dic)

# %%
OpSys_dic
# Out:
# {'Windows 10': 1,
#  'No OS': 2,
#  'Linux': 3,
#  'Windows 7': 4,
#  'Chrome OS': 5,
#  'Windows 10 S': 6,
#  'macOS': 7,
#  'Mac OS X': 8,
#  'Android': 9}

# %%
df
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 0           659    Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3
# 1            80    Acer                      Aspire A515-51G-32MX         1
# 2           330    Acer                                  Aspire 5         1
# 3           332    Acer                             Aspire E5-575         1
# 4           377    Acer                                  Aspire 3         1
# ...         ...     ...                                       ...       ...
# 1298       1135    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1
# 1299        888  Xiaomi                               Mi Notebook         2
# 1300        188  Xiaomi                               Mi Notebook         1
# 1301        521  Xiaomi                               Mi Notebook         1
# 1302        196  Xiaomi                               Mi Notebook         2
#
# ...

# %%
df['Inches'].nunique()
# Out:
# 18

# %%
Inches_dic ={15.6:1, 14:2 , 17:3 , 17.3:4, 13.3:5, 12.5:6, 11.6:7, 12.3:8, 18.4:9, 15.:10 , 12. :11,
       15.4:12, 13.:13 , 13.5:14, 14.1:15, 11.3:16, 13.9:17, 10.1:18}
df['Inches'] = df['Inches'].map(Inches_dic)

# %%
Inches_dic
# Out:
# {15.6: 1,
#  14: 2,
#  17: 3,
#  17.3: 4,
#  13.3: 5,
#  12.5: 6,
#  11.6: 7,
#  12.3: 8,
#  18.4: 9,
#  15.0: 10,
#  12.0: 11,
#  15.4: 12,
#  13.0: 13,
#  13.5: 14,
#  14.1: 15,
#  11.3: 16,
#  13.9: 17,
#  10.1: 18}

# %%
df
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 0           659    Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3
# 1            80    Acer                      Aspire A515-51G-32MX         1
# 2           330    Acer                                  Aspire 5         1
# 3           332    Acer                             Aspire E5-575         1
# 4           377    Acer                                  Aspire 3         1
# ...         ...     ...                                       ...       ...
# 1298       1135    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1
# 1299        888  Xiaomi                               Mi Notebook         2
# 1300        188  Xiaomi                               Mi Notebook         1
# 1301        521  Xiaomi                               Mi Notebook         1
# 1302        196  Xiaomi                               Mi Notebook         2
#
# ...

# %%
df['Cpu'].nunique()
# Out:
# 118

# %%
df = df.drop(columns=['laptop_ID'])

# %%
df
# Out:
#      Company                                   Product  TypeName  Inches  \
# 0       Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3       1
# 1       Acer                      Aspire A515-51G-32MX         1       1
# 2       Acer                                  Aspire 5         1       1
# 3       Acer                             Aspire E5-575         1       1
# 4       Acer                                  Aspire 3         1       1
# ...      ...                                       ...       ...     ...
# 1298    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1       5
# 1299  Xiaomi                               Mi Notebook         2       5
# 1300  Xiaomi                               Mi Notebook         1       1
# 1301  Xiaomi                               Mi Notebook         1       1
# 1302  Xiaomi                               Mi Notebook         2       5
#
#                  ScreenResolution                          Cpu  Ram  Memory  \
# ...

# %%
df['Product'].nunique()
# Out:
# 618

# %%
df['ScreenResolution'].unique()
# Out:
# <StringArray>
# [                            'Full HD 1920x1080',
#                                       '1366x768',
#                             'IPS Panel 1366x768',
#      'IPS Panel Full HD / Touchscreen 1920x1080',
#                    'IPS Panel Full HD 1920x1080',
#                 'IPS Panel Touchscreen 1366x768',
#                                       '1600x900',
#             'IPS Panel Retina Display 2304x1440',
#             'IPS Panel Retina Display 2560x1600',
#             'IPS Panel Retina Display 2880x1800',
#                                       '1440x900',
#                'IPS Panel 4K Ultra HD 3840x2160',
#                'Full HD / Touchscreen 1920x1080',
#                           'Touchscreen 1366x768',
#                   'IPS Panel Quad HD+ 3200x1800',
#                                      '1920x1080',
#                'Touchscreen / Full HD 1920x1080',
#            '4K Ultra HD / Touchscreen 3840x2160',
# ...

# %%
ScreenResolution_dic = { 'Full HD 1920x1080': 0,
    '1366x768': 1,
    'IPS Panel 1366x768': 2,
    'IPS Panel Full HD / Touchscreen 1920x1080': 3,
    'IPS Panel Full HD 1920x1080': 4,
    'IPS Panel Touchscreen 1366x768': 5,
    '1600x900': 6,
    'IPS Panel Retina Display 2304x1440': 7,
    'IPS Panel Retina Display 2560x1600': 8,
    'IPS Panel Retina Display 2880x1800': 9,
    '1440x900': 10,
    'IPS Panel 4K Ultra HD 3840x2160': 11,
    'Full HD / Touchscreen 1920x1080': 12,
    'Touchscreen 1366x768': 13,
    'IPS Panel Quad HD+ 3200x1800': 14,
    '1920x1080': 15,
    'Touchscreen / Full HD 1920x1080': 16,
    '4K Ultra HD / Touchscreen 3840x2160': 17,
    'Quad HD+ 3200x1800': 18,
    'IPS Panel Retina Display 2736x1824': 19,
    '4K Ultra HD 3840x2160': 20,
    'IPS Panel Touchscreen / 4K Ultra HD 3840x2160': 21,
    'IPS Panel 4K Ultra HD / Touchscreen 3840x2160': 22,
    'Quad HD+ / Touchscreen 3200x1800': 23,
    'IPS Panel Full HD 1920x1200': 24,
    'Touchscreen 2256x1504': 25,
    'Touchscreen / 4K Ultra HD 3840x2160': 26,
    'IPS Panel Touchscreen 2400x1600': 27}
df['ScreenResolution'] = df['ScreenResolution'].map(ScreenResolution_dic)

# %%
ScreenResolution_dic
# Out:
# {'Full HD 1920x1080': 0,
#  '1366x768': 1,
#  'IPS Panel 1366x768': 2,
#  'IPS Panel Full HD / Touchscreen 1920x1080': 3,
#  'IPS Panel Full HD 1920x1080': 4,
#  'IPS Panel Touchscreen 1366x768': 5,
#  '1600x900': 6,
#  'IPS Panel Retina Display 2304x1440': 7,
#  'IPS Panel Retina Display 2560x1600': 8,
#  'IPS Panel Retina Display 2880x1800': 9,
#  '1440x900': 10,
#  'IPS Panel 4K Ultra HD 3840x2160': 11,
#  'Full HD / Touchscreen 1920x1080': 12,
#  'Touchscreen 1366x768': 13,
#  'IPS Panel Quad HD+ 3200x1800': 14,
#  '1920x1080': 15,
#  'Touchscreen / Full HD 1920x1080': 16,
#  '4K Ultra HD / Touchscreen 3840x2160': 17,
#  'Quad HD+ 3200x1800': 18,
#  'IPS Panel Retina Display 2736x1824': 19,
#  '4K Ultra HD 3840x2160': 20,
#  'IPS Panel Touchscreen / 4K Ultra HD 3840x2160': 21,
#  'IPS Panel 4K Ultra HD / Touchscreen 3840x2160': 22,
#  'Quad HD+ / Touchscreen 3200x1800': 23,
#  'IPS Panel Full HD 1920x1200': 24,
#  'Touchscreen 2256x1504': 25,
# ...

# %%
df
# Out:
#      Company                                   Product  TypeName  Inches  \
# 0       Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3       1
# 1       Acer                      Aspire A515-51G-32MX         1       1
# 2       Acer                                  Aspire 5         1       1
# 3       Acer                             Aspire E5-575         1       1
# 4       Acer                                  Aspire 3         1       1
# ...      ...                                       ...       ...     ...
# 1298    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1       5
# 1299  Xiaomi                               Mi Notebook         2       5
# 1300  Xiaomi                               Mi Notebook         1       1
# 1301  Xiaomi                               Mi Notebook         1       1
# 1302  Xiaomi                               Mi Notebook         2       5
#
#       ScreenResolution                          Cpu  Ram  Memory  \
# ...

# %%
df = df.drop(columns=['Gpu'])

# %%
df
# Out:
#      Company                                   Product  TypeName  Inches  \
# 0       Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3       1
# 1       Acer                      Aspire A515-51G-32MX         1       1
# 2       Acer                                  Aspire 5         1       1
# 3       Acer                             Aspire E5-575         1       1
# 4       Acer                                  Aspire 3         1       1
# ...      ...                                       ...       ...     ...
# 1298    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1       5
# 1299  Xiaomi                               Mi Notebook         2       5
# 1300  Xiaomi                               Mi Notebook         1       1
# 1301  Xiaomi                               Mi Notebook         1       1
# 1302  Xiaomi                               Mi Notebook         2       5
#
#       ScreenResolution                          Cpu  Ram  Memory  OpSys  \
# ...

# %%
df
# Out:
#      Company                                   Product  TypeName  Inches  \
# 0       Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3       1
# 1       Acer                      Aspire A515-51G-32MX         1       1
# 2       Acer                                  Aspire 5         1       1
# 3       Acer                             Aspire E5-575         1       1
# 4       Acer                                  Aspire 3         1       1
# ...      ...                                       ...       ...     ...
# 1298    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1       5
# 1299  Xiaomi                               Mi Notebook         2       5
# 1300  Xiaomi                               Mi Notebook         1       1
# 1301  Xiaomi                               Mi Notebook         1       1
# 1302  Xiaomi                               Mi Notebook         2       5
#
#       ScreenResolution                          Cpu  Ram  Memory  OpSys  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Company                                   Product  TypeName  Inches  \
# 0       Acer  A715-71G-59DH (i5-7300HQ/8GB/1TB/GeForce         3       1
# 1       Acer                      Aspire A515-51G-32MX         1       1
# 2       Acer                                  Aspire 5         1       1
# 3       Acer                             Aspire E5-575         1       1
# 4       Acer                                  Aspire 3         1       1
# ...      ...                                       ...       ...     ...
# 1298    Vero          V131 (X5-Z8350/4GB/32GB/FHD/W10)         1       5
# 1299  Xiaomi                               Mi Notebook         2       5
# 1300  Xiaomi                               Mi Notebook         1       1
# 1301  Xiaomi                               Mi Notebook         1       1
# 1302  Xiaomi                               Mi Notebook         2       5
#
#       ScreenResolution                          Cpu  Ram  Memory  OpSys  \
# ...

# %%
df['TypeName'].unique()
# Out:
# array([3, 1, 4, 5, 2, 6])

# %%
df = df.drop(columns=['Product'])

# %%
df
# Out:
#      Company  TypeName  Inches  ScreenResolution                          Cpu  \
# 0       Acer         3       1               0.0  Intel Core i5 7300HQ 2.5GHz
# 1       Acer         1       1               0.0   Intel Core i3 7130U 2.7GHz
# 2       Acer         1       1               1.0  AMD A12-Series 9720P 2.7GHz
# 3       Acer         1       1               1.0   Intel Core i5 7200U 2.5GHz
# 4       Acer         1       1               1.0      AMD A9-Series 9420 3GHz
# ...      ...       ...     ...               ...                          ...
# 1298    Vero         1       5               0.0  Intel Atom X5-Z8350 1.44GHz
# 1299  Xiaomi         2       5               4.0   Intel Core i5 6200U 2.3GHz
# 1300  Xiaomi         1       1               4.0   Intel Core i5 8250U 1.6GHz
# 1301  Xiaomi         1       1               4.0   Intel Core i7 8550U 1.8GHz
# 1302  Xiaomi         2       5               4.0   Intel Core i5 7200U 2.5GHz
#
# ...

# %%
df = df.drop(columns=['ScreenResolution'])

# %%
df
# Out:
#      Company  TypeName  Inches                          Cpu  Ram  Memory  \
# 0       Acer         3       1  Intel Core i5 7300HQ 2.5GHz    1       3
# 1       Acer         1       1   Intel Core i3 7130U 2.7GHz    3       3
# 2       Acer         1       1  AMD A12-Series 9720P 2.7GHz    1       4
# 3       Acer         1       1   Intel Core i5 7200U 2.5GHz    6       3
# 4       Acer         1       1      AMD A9-Series 9420 3GHz    3       6
# ...      ...       ...     ...                          ...  ...     ...
# 1298    Vero         1       5  Intel Atom X5-Z8350 1.44GHz    3      10
# 1299  Xiaomi         2       5   Intel Core i5 6200U 2.3GHz    1       4
# 1300  Xiaomi         1       1   Intel Core i5 8250U 1.6GHz    1       4
# 1301  Xiaomi         1       1   Intel Core i7 8550U 1.8GHz    2       4
# 1302  Xiaomi         2       5   Intel Core i5 7200U 2.5GHz    1       4
#
#       OpSys  Weight  Price_euros
# 0         3   2.4kg       709.00
# ...

# %%
df = df.drop(columns=['Cpu'])

# %%
df = df.drop(columns=['Weight'])

# %%
df
# Out:
#      Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0       Acer         3       1    1       3      3       709.00
# 1       Acer         1       1    3       3      1       530.00
# 2       Acer         1       1    1       4      1       659.00
# 3       Acer         1       1    6       3      1       549.00
# 4       Acer         1       1    3       6      1       426.00
# ...      ...       ...     ...  ...     ...    ...          ...
# 1298    Vero         1       5    3      10      1       196.00
# 1299  Xiaomi         2       5    1       4      1       935.00
# 1300  Xiaomi         1       1    1       4      2      1199.00
# 1301  Xiaomi         1       1    2       4      2      1399.95
# 1302  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
df
# Out:
#      Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0       Acer         3       1    1       3      3       709.00
# 1       Acer         1       1    3       3      1       530.00
# 2       Acer         1       1    1       4      1       659.00
# 3       Acer         1       1    6       3      1       549.00
# 4       Acer         1       1    3       6      1       426.00
# ...      ...       ...     ...  ...     ...    ...          ...
# 1298    Vero         1       5    3      10      1       196.00
# 1299  Xiaomi         2       5    1       4      1       935.00
# 1300  Xiaomi         1       1    1       4      2      1199.00
# 1301  Xiaomi         1       1    2       4      2      1399.95
# 1302  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
df.to_csv('laptop_clean.csv')

# %%
df
# Out:
#      Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0       Acer         3       1    1       3      3       709.00
# 1       Acer         1       1    3       3      1       530.00
# 2       Acer         1       1    1       4      1       659.00
# 3       Acer         1       1    6       3      1       549.00
# 4       Acer         1       1    3       6      1       426.00
# ...      ...       ...     ...  ...     ...    ...          ...
# 1298    Vero         1       5    3      10      1       196.00
# 1299  Xiaomi         2       5    1       4      1       935.00
# 1300  Xiaomi         1       1    1       4      2      1199.00
# 1301  Xiaomi         1       1    2       4      2      1399.95
# 1302  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]
