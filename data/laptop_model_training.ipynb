# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('laptop_clean.csv')

# %%
df
# Out:
#       Unnamed: 0 Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0              0    Acer         3       1    1       3      3       709.00
# 1              1    Acer         1       1    3       3      1       530.00
# 2              2    Acer         1       1    1       4      1       659.00
# 3              3    Acer         1       1    6       3      1       549.00
# 4              4    Acer         1       1    3       6      1       426.00
# ...          ...     ...       ...     ...  ...     ...    ...          ...
# 1258        1298    Vero         1       5    3      10      1       196.00
# 1259        1299  Xiaomi         2       5    1       4      1       935.00
# 1260        1300  Xiaomi         1       1    1       4      2      1199.00
# 1261        1301  Xiaomi         1       1    2       4      2      1399.95
# 1262        1302  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 8 columns]

# %%
df.drop('Unnamed: 0', axis= 1, inplace= True)

# %%
df
# Out:
#      Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0       Acer         3       1    1       3      3       709.00
# 1       Acer         1       1    3       3      1       530.00
# 2       Acer         1       1    1       4      1       659.00
# 3       Acer         1       1    6       3      1       549.00
# 4       Acer         1       1    3       6      1       426.00
# ...      ...       ...     ...  ...     ...    ...          ...
# 1258    Vero         1       5    3      10      1       196.00
# 1259  Xiaomi         2       5    1       4      1       935.00
# 1260  Xiaomi         1       1    1       4      2      1199.00
# 1261  Xiaomi         1       1    2       4      2      1399.95
# 1262  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(37)

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Inches         0
# Ram            0
# Memory         0
# OpSys          0
# Price_euros    0
# dtype: int64

# %%
df
# Out:
#      Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0       Acer         3       1    1       3      3       709.00
# 1       Acer         1       1    3       3      1       530.00
# 2       Acer         1       1    1       4      1       659.00
# 3       Acer         1       1    6       3      1       549.00
# 4       Acer         1       1    3       6      1       426.00
# ...      ...       ...     ...  ...     ...    ...          ...
# 1258    Vero         1       5    3      10      1       196.00
# 1259  Xiaomi         2       5    1       4      1       935.00
# 1260  Xiaomi         1       1    1       4      2      1199.00
# 1261  Xiaomi         1       1    2       4      2      1399.95
# 1262  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
df
# Out:
#      Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0       Acer         3       1    1       3      3       709.00
# 1       Acer         1       1    3       3      1       530.00
# 2       Acer         1       1    1       4      1       659.00
# 3       Acer         1       1    6       3      1       549.00
# 4       Acer         1       1    3       6      1       426.00
# ...      ...       ...     ...  ...     ...    ...          ...
# 1258    Vero         1       5    3      10      1       196.00
# 1259  Xiaomi         2       5    1       4      1       935.00
# 1260  Xiaomi         1       1    1       4      2      1199.00
# 1261  Xiaomi         1       1    2       4      2      1399.95
# 1262  Xiaomi         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
df['Company'].unique()
# Out:
# <StringArray>
# [     'Acer',     'Apple',      'Asus',     'Chuwi',      'Dell',   'Fujitsu',
#         'HP',        'LG',    'Lenovo',       'MSI',  'Mediacom', 'Microsoft',
#      'Razer',   'Samsung',   'Toshiba',      'Vero',    'Xiaomi']
# Length: 17, dtype: str

# %%
company_dic = {'Acer': 0,
    'Apple': 1,
    'Asus': 2,
    'Chuwi': 3,
    'Dell': 4,
    'Fujitsu': 5,
    'HP': 6,
    'LG': 7,
    'Lenovo': 8,
    'MSI': 9,
    'Mediacom': 10,
    'Microsoft': 11,
    'Razer': 12,
    'Samsung': 13,
    'Toshiba': 14,
    'Vero': 15,
    'Xiaomi': 16}
df['Company'] =df['Company'].map(company_dic)

# %%
company_dic
# Out:
# {'Acer': 0,
#  'Apple': 1,
#  'Asus': 2,
#  'Chuwi': 3,
#  'Dell': 4,
#  'Fujitsu': 5,
#  'HP': 6,
#  'LG': 7,
#  'Lenovo': 8,
#  'MSI': 9,
#  'Mediacom': 10,
#  'Microsoft': 11,
#  'Razer': 12,
#  'Samsung': 13,
#  'Toshiba': 14,
#  'Vero': 15,
#  'Xiaomi': 16}

# %%
df
# Out:
#       Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0           0         3       1    1       3      3       709.00
# 1           0         1       1    3       3      1       530.00
# 2           0         1       1    1       4      1       659.00
# 3           0         1       1    6       3      1       549.00
# 4           0         1       1    3       6      1       426.00
# ...       ...       ...     ...  ...     ...    ...          ...
# 1258       15         1       5    3      10      1       196.00
# 1259       16         2       5    1       4      1       935.00
# 1260       16         1       1    1       4      2      1199.00
# 1261       16         1       1    2       4      2      1399.95
# 1262       16         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Inches         0
# Ram            0
# Memory         0
# OpSys          0
# Price_euros    0
# dtype: int64

# %%
y = df['Price_euros']

# %%
y
# Out:
# 0        709.00
# 1        530.00
# 2        659.00
# 3        549.00
# 4        426.00
#          ...
# 1258     196.00
# 1259     935.00
# 1260    1199.00
# 1261    1399.95
# 1262     999.90
# Name: Price_euros, Length: 1263, dtype: float64

# %%
x = df[['Company','TypeName','Ram', 'OpSys','Inches']]
y = df['Price_euros']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3,random_state=10)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([ 698.94492124, 1545.37659707,  847.6406952 , 1809.14095961,
#         766.58598348,  834.22704572, 1403.78655172,  586.1776633 ,
#        1405.76835   ,  914.9538721 , 1459.68183919, 1584.40539433,
#        1475.85254284, 1408.99481787, 1552.44929856, 1613.01765931,
#         932.96971213,  867.14126786,  723.92147502, 1157.84680576,
#        1928.77361152,  770.54958003,  867.14126786,  951.67298574,
#         681.25696656, 1279.65808821,  862.10218202, 1914.1397295 ,
#        1264.68584557,  681.25696656, 1244.59288749,  702.90851779,
#         994.49619924,  832.24524745, 1148.65077764, 1200.67001927,
#         617.57950086,  744.93443225, 1152.9527348 , 1578.1216389 ,
#         744.93443225, 1554.12254844, 1246.57468577, 1172.05775429,
#        1268.64944212, 1457.70004092,  832.24524745, 1009.63762219,
#        1279.65808821,  832.24524745, 1926.79181325,  766.58598348,
#         834.22704572, 1029.56139996,  702.90851779, 1504.5110164 ,
# ...

# %%
print("test score",model.score(x_test,y_test))
print("train score",model.score(x_train,y_train))
# Out:
# test score 0.2832605866436343
# train score 0.2046665613403258

# %%
df
# Out:
#       Company  TypeName  Inches  Ram  Memory  OpSys  Price_euros
# 0           0         3       1    1       3      3       709.00
# 1           0         1       1    3       3      1       530.00
# 2           0         1       1    1       4      1       659.00
# 3           0         1       1    6       3      1       549.00
# 4           0         1       1    3       6      1       426.00
# ...       ...       ...     ...  ...     ...    ...          ...
# 1258       15         1       5    3      10      1       196.00
# 1259       16         2       5    1       4      1       935.00
# 1260       16         1       1    1       4      2      1199.00
# 1261       16         1       1    2       4      2      1399.95
# 1262       16         2       5    1       4      2       999.90
#
# [1263 rows x 7 columns]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state=45)

# %%
from sklearn.ensemble import RandomForestRegressor

rt = RandomForestRegressor()
rt.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 from sklearn.ensemble import RandomForestRegressor
#       2
#       3 rt = RandomForestRegressor()
# ----> 4 rt.fit(X, y)
#
# NameError: name 'X' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rt=RandomForestRegressor()
rt.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import os

os.makedirs("model", exist_ok=True)

# %%
import joblib

joblib.dump(rt, "model/rt.lb")
# Out:
# ['model/rt.lb']

# %%
print(X.columns)
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Memory', 'OpSys'], dtype='str')

# %%
import os
import joblib

os.makedirs("model", exist_ok=True)

joblib.dump(rt, "model/rt.lb")

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
rt=RandomForestRegressor()
rt.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import os

print(os.listdir("model"))
# Out:
# ['rt.lb']

# %%
model = joblib.load("model/rt.lb")

# %%
print(rt)
# Out:
# RandomForestRegressor()

# %%
X = df.drop("Price_euros", axis=1)
y = df["Price_euros"]

rt.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
import os
import joblib

os.makedirs("model", exist_ok=True)

joblib.dump(rt, "model/rt.lb")
# Out:
# ['model/rt.lb']

# %%
import os
print(os.listdir("model"))
# Out:
# ['rt.lb']
